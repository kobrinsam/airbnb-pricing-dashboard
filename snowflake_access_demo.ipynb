# %% [markdown]
# # Tutorial on Accessing Snowflake
# Install the snowflake-connector-python if needed

# %%
# !pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (2022.12.7)
# Requirement already satisfied: requests<3.0.0 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (2.28.1)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (3.4.8)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: packaging in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (21.3)
# Requirement already satisfied: pytz in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (2021.3)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: filelock<4,>=3.5 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (3.6.0)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (2.1.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (4.2.2)
# Requirement already satisfied: tomlkit in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (0.11.6)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (21.0.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.21.1 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (1.26.13)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (4.5.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from snowflake-connector-python) (1.15.0)
# Requirement already satisfied: pycparser in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: six>=1.5.2 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from pyOpenSSL<25.0.0,>=16.2.0->snowflake-connector-python) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/samkobrin/opt/anaconda3/lib/python3.9/site-packages (from packaging->snowflake-connector-python) (3.0.4)

# %%
import pandas as pd
import snowflake.connector
import os
from datetime import datetime
from dotenv import load_dotenv

# enable pandas to display up to 500 columns
pd.set_option('display.max_columns', 500)

# %% [markdown]
# #### 1.1 Load Snowflake credentials for temp user

# %%
# Load environment variables from a .env file
load_dotenv()

try:
    TEMP_USER = os.getenv('SNOWSQL_TEMP_USER')
    TEMP_USER_PASSWORD = os.getenv('SNOWSQL_TEMP_PWD')
    
    if not TEMP_USER:
        raise ValueError("Environment variable SNOWSQL_TEMP_USER must be set")
    if not TEMP_USER_PASSWORD:
        raise ValueError("Environment variable SNOWSQL_TEMP_PWD must be set")

except ValueError as ve:
    print(f"Error: {ve}")
    
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %% [markdown]
# #### 1.2 Connect to Snowflake

# %%
# Establish connection to Snowflake
current_time = datetime.now().strftime('%Y-%m-%d %H:%M%S')

try:
    conn = snowflake.connector.connect(
        user=TEMP_USER,
        password=TEMP_USER_PASSWORD,
        account='ygeuort-alb19263',
        warehouse='COMPUTE_WH',
        database='AIRBNB',
        schema='ODS'
    )

    print(f'Connected to Snowflake successfully at {current_time}')

except Exception as e:
    print(f'Failed to connect to Snowflake on {current_time} due to error code {e}')
# Out:
# Connected to Snowflake successfully at 2024-07-19 14:5720

# %% [markdown]
# ## 2. Fetch data from Snowflake
#
# ### Table Information
#
# The following tables exist in the ODS schema:
#
# **listings table**:  contains data on listings
# - Number of rows:  111K.
# - Date columns: 'last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review'
#
# **reviews table**:  contains reviews for listings
# - Number of rows: 4.1M rows.
# - Date columns: 'review_date'
#
# ### Market Names
#
# Market names are stored under the column `market` for each table and markets are labeled as follows:
# - albany
# - chicago
# - los-angeles
# - new-york-city
# - san-francisco
# - seattle
# - washington-dc
#
# #### 2.1 Function to fetch data from Snowflake

# %%
def get_data(sql_query, date_columns=None):
    """
    Executes a SQL query and returns the result as a pandas DataFrame.

    Args:
        sql_query (str): SQL query to execute.

    Returns:
        df_result: Resulting DataFrame from the SQL query.
    """
    try:
        cursor = conn.cursor()
        
        cursor.execute(sql_query)

        # load data into dataframe
        df_result = cursor.fetch_pandas_all()

        # Convert column names to lowercase
        df_result.columns = map(str.lower, df_result.columns)

        # Parse specified date columns
        if date_columns:
            for col in date_columns:
                df_result[col] = pd.to_datetime(df_result[col], errors='coerce')

    finally:
        if cursor is not None:
            cursor.close()

    return df_result

# %% [markdown]
# #### 2.2 Sample query
# Select listings data for albany market.

# %%
sql_query = '''
select * from listings
where market = 'chicago'
 '''

df = get_data(sql_query)
df.shape
# Out:
# (7707, 68)

# %%
df.head()
# Out:
#       id       scrape_id last_scraped  \
# 0   2384  20240323200240   2024-03-23
# 1   7126  20240323200240   2024-03-24
# 2  10945  20240323200240   2024-03-24
# 3  12140  20240323200240   2024-03-24
# 4  24833  20240323200240   2024-03-24
#
#                                                 name  \
# 0                       Hyde Park - Walk to UChicago
# 1                Tiny Studio Apartment 94 Walk Score
# 2                              The Biddle House (#1)
# 3                           Lincoln Park Guest House
# 4  Prime LincolnPark 1 Block Fullerton Express L ...
#
#                                          description  \
# 0  You are invited stay in the guest room of my v...
# 1   A very small studio in a wonderful neighborhood.
# 2  Beautiful first floor apartment in Historic Ol...
# 3  Bed and Breakfast license issued by the City o...
# 4  Perfect private entrance apartment one block f...
#
#                                neighborhood_overview  host_id  \
# 0  The apartment is less than one block from beau...     2613
# 1  Ukrainian Village was just named "Hottest Neig...    17928
# 2                                               None    33004
# 3  The Guest House is in the heart of Chicago's m...    46734
# 4  Lincoln Park is a great neighborhood where peo...   101521
#
#          host_name  host_since host_location  \
# 0          Rebecca  2008-08-29   Chicago, IL
# 1            Sarah  2009-05-19   Chicago, IL
# 2      At Home Inn  2009-08-21   Chicago, IL
# 3  Shay And Robert  2009-10-18   Chicago, IL
# 4              Red  2010-03-31   Chicago, IL
#
#                                           host_about  host_response_time  \
# 0  My apartment is a 2nd floor walk-up in a centu...      within an hour
# 1  We live in Chicago. We love to travel and see ...      within an hour
# 2  Hi, we're Bob and Liz Biddle, long time Chicag...      within an hour
# 3  Best in the city with long-time urban-dwelling...        within a day
# 4  Travel is fun and exciting but can be hard on ...  within a few hours
#
#    host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0               100.0                  91.0                  1
# 1               100.0                 100.0                  1
# 2                97.0                  93.0                  1
# 3               100.0                 100.0                  0
# 4               100.0                  85.0                  1
#
#   host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0          Hyde Park                    1                          1
# 1  Ukrainian Village                    1                          2
# 2           Old Town                    9                         86
# 3       Lincoln Park                    1                          1
# 4       Lincoln Park                    9                         13
#
#          host_verifications host_has_profile_pic host_identity_verified  \
# 0              email, phone                    t                      t
# 1              email, phone                    t                      t
# 2  email, phone, work_email                    t                      t
# 3              email, phone                    t                      t
# 4              email, phone                    t                      t
#
#                       neighbourhood neighbourhood_cleansed   latitude  \
# 0  Chicago, Illinois, United States              Hyde Park  41.787900
# 1  Chicago, Illinois, United States              West Town  41.901660
# 2                              None           Lincoln Park  41.911960
# 3  Chicago, Illinois, United States           Lincoln Park  41.923570
# 4  Chicago, Illinois, United States           Lincoln Park  41.925961
#
#    longitude           property_type        room_type  accommodates  \
# 0 -87.587800   Private room in condo     Private room             1
# 1 -87.680210      Entire rental unit  Entire home/apt             2
# 2 -87.639810      Entire rental unit  Entire home/apt             4
# 3 -87.649470  Room in boutique hotel     Private room             3
# 4 -87.656364      Entire rental unit  Entire home/apt             3
#
#    bathrooms  bathrooms_text  bedrooms  beds  \
# 0        1.0   1 shared bath       1.0   1.0
# 1        1.0          1 bath       1.0   1.0
# 2        1.0          1 bath       2.0   2.0
# 3        1.0  1 private bath       1.0   1.0
# 4        1.0          1 bath       1.0   1.0
#
#                                            amenities  price  minimum_nights  \
# 0  Free washer - In building, Coffee, Books and r...   86.0               3
# 1  Smart lock, Books and reading material, Window...   90.0               2
# 2  Free washer - In building, Lake access, Window...  114.0               4
# 3  Fire extinguisher, Iron, Heating, Shampoo, Han...  329.0               2
# 4  Drying rack for clothing, Free washer - In bui...   57.0              32
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              89                       2                       3
# 1              60                       2                       2
# 2             120                       2                       4
# 3              10                       1                       2
# 4             395                      32                      32
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                     3.0
# 1                    1125                    1125                     2.0
# 2                    1125                    1125                     3.9
# 3                      10                      10                     2.0
# 4                     395                     395                    32.0
#
#    maximum_nights_avg_ntm has_availability  availability_30  availability_60  \
# 0                  1125.0                t               13               36
# 1                  1125.0                t               20               43
# 2                  1125.0                t                6               19
# 3                    10.0                t               29               54
# 4                   395.0                t                0               18
#
#    availability_90  availability_365 calendar_last_scraped  number_of_reviews  \
# 0               62               309            2024-03-23                234
# 1               61               294            2024-03-24                516
# 2               26               162            2024-03-24                 83
# 3               78               165            2024-03-24                 15
# 4               18               239            2024-03-24                 40
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                     23                       2   2015-01-09  2024-03-12
# 1                     31                       1   2009-07-03  2024-03-03
# 2                     23                       1   2014-04-28  2024-03-06
# 3                      2                       0   2015-06-29  2023-05-21
# 4                      1                       0   2010-05-24  2023-04-22
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.99                    4.98                       4.99
# 1                  4.70                    4.85                       4.56
# 2                  4.65                    4.80                       4.80
# 3                  4.93                    4.67                       5.00
# 4                  4.29                    4.07                       4.00
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.99                         4.98                    4.96
# 1                   4.90                         4.87                    4.89
# 2                   4.80                         4.84                    4.98
# 3                   5.00                         5.00                    5.00
# 4                   4.13                         4.03                    4.90
#
#    review_scores_value                    license instant_bookable  \
# 0                 4.94               R17000015609                f
# 1                 4.75               R24000114046                f
# 2                 4.66                    2209984                t
# 3                 4.87               R20000055258                f
# 4                 4.20  City registration pending                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               6
# 3                               1
# 4                               4
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            6
# 3                                            0
# 4                                            4
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month   market
# 0                                            0               2.09  chicago
# 1                                            0               2.88  chicago
# 2                                            0               0.69  chicago
# 3                                            0               0.14  chicago
# 4                                            0               0.24  chicago

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7707 entries, 0 to 7706
# Data columns (total 68 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7707 non-null   int64
#  1   scrape_id                                     7707 non-null   int64
#  2   last_scraped                                  7707 non-null   object
#  3   name                                          7707 non-null   object
#  4   description                                   7622 non-null   object
#  5   neighborhood_overview                         5428 non-null   object
#  6   host_id                                       7707 non-null   int32
#  7   host_name                                     7707 non-null   object
#  8   host_since                                    7707 non-null   object
#  9   host_location                                 6288 non-null   object
#  10  host_about                                    5238 non-null   object
#  11  host_response_time                            7213 non-null   object
#  12  host_response_rate                            7213 non-null   float64
#  13  host_acceptance_rate                          7377 non-null   float64
#  14  host_is_superhost                             7707 non-null   int8
#  15  host_neighbourhood                            7504 non-null   object
#  16  host_listings_count                           7707 non-null   int16
#  17  host_total_listings_count                     7707 non-null   int16
#  18  host_verifications                            7707 non-null   object
#  19  host_has_profile_pic                          7707 non-null   object
#  20  host_identity_verified                        7707 non-null   object
#  21  neighbourhood                                 5429 non-null   object
#  22  neighbourhood_cleansed                        7707 non-null   object
#  23  latitude                                      7707 non-null   float64
#  24  longitude                                     7707 non-null   float64
#  25  property_type                                 7707 non-null   object
#  26  room_type                                     7707 non-null   object
#  27  accommodates                                  7707 non-null   int8
#  28  bathrooms                                     7521 non-null   float64
#  29  bathrooms_text                                7696 non-null   object
#  30  bedrooms                                      7664 non-null   float64
#  31  beds                                          7494 non-null   float64
#  32  amenities                                     7707 non-null   object
#  33  price                                         7473 non-null   float64
#  34  minimum_nights                                7707 non-null   int16
#  35  maximum_nights                                7707 non-null   int32
#  36  minimum_minimum_nights                        7707 non-null   int16
#  37  maximum_minimum_nights                        7707 non-null   int16
#  38  minimum_maximum_nights                        7707 non-null   int32
#  39  maximum_maximum_nights                        7707 non-null   int32
#  40  minimum_nights_avg_ntm                        7707 non-null   float64
#  41  maximum_nights_avg_ntm                        7707 non-null   float64
#  42  has_availability                              7671 non-null   object
#  43  availability_30                               7707 non-null   int8
#  44  availability_60                               7707 non-null   int8
#  45  availability_90                               7707 non-null   int8
#  46  availability_365                              7707 non-null   int16
#  47  calendar_last_scraped                         7707 non-null   object
#  48  number_of_reviews                             7707 non-null   int16
#  49  number_of_reviews_ltm                         7707 non-null   int16
#  50  number_of_reviews_l30d                        7707 non-null   int8
#  51  first_review                                  6152 non-null   object
#  52  last_review                                   6152 non-null   object
#  53  review_scores_rating                          6152 non-null   float64
#  54  review_scores_accuracy                        6144 non-null   float64
#  55  review_scores_cleanliness                     6143 non-null   float64
#  56  review_scores_checkin                         6144 non-null   float64
#  57  review_scores_communication                   6144 non-null   float64
#  58  review_scores_location                        6144 non-null   float64
#  59  review_scores_value                           6144 non-null   float64
#  60  license                                       7707 non-null   object
#  61  instant_bookable                              7707 non-null   object
#  62  calculated_host_listings_count                7707 non-null   int16
#  63  calculated_host_listings_count_entire_homes   7707 non-null   int16
#  64  calculated_host_listings_count_private_rooms  7707 non-null   int16
#  65  calculated_host_listings_count_shared_rooms   7707 non-null   int8
#  66  reviews_per_month                             6152 non-null   float64
#  67  market                                        7707 non-null   object
# dtypes: float64(18), int16(11), int32(4), int64(2), int8(7), object(26)
# memory usage: 3.0+ MB

# %% [markdown]
# ### 2.3 Sample query with date conversion for date columns
# All Listings data and convert date columns to date type.

# %%
date_cols = ['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review']

sql_query = '''
select * from listings
 '''

df = get_data(sql_query, date_columns=date_cols)
df.shape
# Out:
# (111052, 68)

# %%
df.info()

# %% [markdown]
# #### 2.4 Sample query for Reviews
# Reviews table contains 4 million reviews. For now just pull in 100 reviews.

# %%
date_cols = ['review_date']

sql_query = '''
select * from reviews
limit 100
 '''

df = get_data(sql_query, date_columns=date_cols)
df.shape

# %%
df.head()

# %%
df.info()

# %% [markdown]
# ## 3. Loading data into Snowflake
# After performing feature engineering, the data will be stored in a schema called `feature_store`.
#
# In this example we retrieve listings for Albany and prase the dates but limit to the first 10 rows.
# #### 3.1 Load data

# %%
date_cols = ['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review']

sql_query = '''
select * from listings
where market = 'albany'
limit 10
 '''

df = get_data(sql_query, date_columns=date_cols)
df.shape

# %%
df

# %% [markdown]
# #### 3.2 Create new feature

# %%
df['new_feature'] = 'feature'

# %%
df.head(2)

# %% [markdown]
# #### 3.3 Connect to FEATURE_STORE schema

# %%
# Establish connection to Snowflake
current_time = datetime.now().strftime('%Y-%m-%d %H:%M%S')

try:
    conn = snowflake.connector.connect(
        user=TEMP_USER,
        password=TEMP_USER_PASSWORD,
        account='ygeuort-alb19263',
        warehouse='COMPUTE_WH',
        database='AIRBNB',
        schema='FEATURE_STORE' # connect to feature_store
    )

    print(f'Connected to Snowflake successfully at {current_time}')

except Exception as e:
    print(f'Failed to connect to Snowflake on {current_time} due to error code {e}')

# %% [markdown]
# #### 3.4 Create table and upload to Snowflake

# %%
from snowflake.connector.pandas_tools import write_pandas

# %%
def write_to_snowflake(df_name, snowflake_table_name):
    current_time = datetime.now().strftime('%Y-%m-%d %H:%M%S')
    try:
        success, num_chunks, num_rows, output = write_pandas(
            conn=conn,
            df=df_name,
            schema='FEATURE_STORE', # schema needs to be capitalized
            table_name=snowflake_table_name,
            auto_create_table=True,
            overwrite=True
        )

        print(f'Created table and data loaded to Snowflake at {current_time}')

    except Exception as e:
        print(f'Failed to create table and load data to Snowflake due to error code {e}')

# %%
write_to_snowflake(df, 'ALBANY_MARKET_LISTINGS')
